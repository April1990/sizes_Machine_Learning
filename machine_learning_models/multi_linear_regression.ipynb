# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
dataset = pd.read_csv(r'../csv/modified_male_female.csv')
for column in dataset.columns:
    if dataset[column].dtype == type(object):

        label_encoder = LabelEncoder()
        dataset[column] = label_encoder.fit_transform(dataset[column])

dataset.head(3)
dataset.tail(3)
# Out:
#       height(cm)  weight(kg)  gender  size
# 6065      167.64   76.203518       0     7
# 6066      160.02   60.327785       0     2
# 6067      167.64   59.874193       0     6

# %%
import seaborn as sns
# %matplotlib inline

sns.pairplot(dataset, hue='size')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = dataset.drop('size', axis = 1)
y = dataset['size']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = .5)

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
person = [[147, 45, 1]]
linear.predict(person)
# Out:
# c:\users\velor\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.42338412])
